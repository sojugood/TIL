# %%
start = balls[0]
target = None
goal = None
rot = 0
R = 5.73

for ball in balls[1:]:
    if ball[0] != -1 and ball[1] != -1:
        target = ball
        break

target_x = target[0]
target_y = target[1]

if target_x - start[0] > 0 and target_y - start[1] < 0:
    target_y = 127 - target_y
    rot += 90
elif target_x - start[0] < 0 and target_y - start[1] < 0:
    target_x = 127 - target_x
    target_y = 127 - target_y
    rot += 180
elif target_x - start[0] < 0 and target_y - start[1] > 0:
    target_x = 127 - target_x
    rot += 270

if target_x > 127 and target_y > 127:
    goal = [254, 127]
else:
    goal = [127, 127]

rad_tmp = math.atan2(goal[1] - target_y, goal[0] - target_x)

temp_x = math.sin(rad_tmp) * R
temp_y = math.cos(rad_tmp) * R

rad_real = math.atan2(target_y - temp_y - start[1], target_x - temp_x - start[0])

angle = (90 - math.degrees(rad_real)) + rot


distance = math.sqrt((target_y - temp_y - start[1])**2 + (target_x - temp_x - start[0])**2)

power = distance * 0.5

# %%
    start = balls[0]
    target = None
    goal = None
    R = 5.73

    for ball in balls[1:]:
        if ball[0] != -1 and ball[1] != -1:
            target = ball
            break

    target_x = target[0]
    target_y = target[1]

    if target_x > 127 and target_y > 64:
        goal = [254, 127]
    elif target_x > 127 and target_y < 64:
        goal = [254, 0]
    elif target_x < 127 and target_y > 64:
        if target_x > 64:
            goal = [127, 127]
        else:
            goal = [0, 127]
    elif target_x < 127 and target_y < 64:
        if target_x > 64:
            goal = [127, 0]
        else:
            goal = [0, 0]

    rad_tmp = math.atan2(goal[1] - target_y, goal[0] - target_x)

    temp_x = math.cos(rad_tmp) * R
    temp_y = math.sin(rad_tmp) * R

    rad_real = math.atan2(target_y - temp_y - start[1], target_x - temp_x - start[0])

    angle = 90 - math.degrees(rad_real)


    distance = math.sqrt((target_y - temp_y - start[1])**2 + (target_x - temp_x - start[0])**2)

    power = distance * 0.3

# %%
    start = balls[0]
    target = None
    goal = None
    rot = 0
    R = 5.73

    for ball in balls[1:]:
        if ball[0] != -1 and ball[1] != -1:
            target = ball
            break

    target_x = target[0]
    target_y = target[1]

    if target_x - start[0] > 0 and target_y - start[1] < 0:
        target_y = 127 - target_y
        rot += 90
    elif target_x - start[0] < 0 and target_y - start[1] < 0:
        target_x = 127 - target_x
        target_y = 127 - target_y
        rot += 180
    elif target_x - start[0] < 0 and target_y - start[1] > 0:
        target_x = 127 - target_x
        rot += 270

    if target_x > 127 and target_y > 127:
        goal = [254, 127]
    else:
        goal = [127, 127]

    rad_tmp = math.atan2(goal[1] - target_y, goal[0] - target_x)

    temp_x = math.cos(rad_tmp) * R
    temp_y = math.sin(rad_tmp) * R

    rad_real = math.atan2(target_y - temp_y - start[1], target_x - temp_x - start[0])

    angle = (90 - math.degrees(rad_real)) + rot


    distance = math.sqrt((target_y - temp_y - start[1])**2 + (target_x - temp_x - start[0])**2)

    power = distance * 0.3
